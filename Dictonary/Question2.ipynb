# %%
#Phone Contact Book
#contacts = {
#    "Ayesha": "03001234567",
#    "Hassan": "03114567890",
#    "Fatima": "03219876543"
#}

#Tasks
#Search phone number of Hassan
#Add a new contact
#Delete Fatima

# %%
contacts = {
    "Ayesha": "03001234567",
    "Hassan": "03114567890",
    "Fatima": "03219876543",
    "Hamza": "03112934858"
}

#Search phone number
print(f"Phone Number of Hassan: {contacts.get('Hassan')} ")

#Add a new contact
contacts["Rabia"] = "0323948393"
print(f"\nNew Contact Added! Successfully \n{contacts}")

#Delete Fatima
del contacts["Fatima"]
print(f"\nContact deleted Successfully! \n{contacts}")
# Out:
# Phone Number of Hassan: 03114567890
#
# New Contact Added! Successfully
# {'Ayesha': '03001234567', 'Hassan': '03114567890', 'Fatima': '03219876543', 'Hamza': '03112934858', 'Rabia': '0323948393'}
#
# Contact deleted Successfully!
# {'Ayesha': '03001234567', 'Hassan': '03114567890', 'Hamza': '03112934858', 'Rabia': '0323948393'}
