# %%
#Password Checker
#Keep asking the user to enter a password until they enter:
#python123
#Output:
#Access Granted

# %%
correct_password = "python123"
password = input("Enter your password")
while password != correct_password:
    password = input("Invalid! password. \n Enter correct password")
print("Access Denied")
# Out:
# Enter your password rabel
# Invalid! password.
#  Enter correct password python123
# Access Denied
