# %%
#Question 4: String Repetition
#Take a word and a number as input from the user. 
#Print that word as many times as the number given.

#Example Output:
#Enter a word: Python
#How many times?: 3
#PythonPythonPython

# %%
word = input("Enter any word
times = int(input("How many times?"))
product =word * times

print("Result: ", product)
# Out:
# Enter any word: Python
# How many times? 3
# Result:  PythonPythonPython
