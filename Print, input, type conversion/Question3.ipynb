# %%
#Question 3: Temperature Converter
#Take temperature in Celsius as input from the user 
#and convert it to Fahrenheit and print the result.

#Formula: F = (C × 9/5) + 32

#Example Output:
#Enter temperature in Celsius: 37
#Temperature in Fahrenheit: 98.6

# %%
Celsius = float(input("Enter the temperature in Celsius: "))

fahrenheit = (Celsius * 9/5) + 32

print("Tempertaure in Fahrenheit is: " , fahrenheit)
# Out:
# Enter the temperature in Celsius:  37
# Tempertaure in Fahrenheit is:  98.6
