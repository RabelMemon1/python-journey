# %%
#Question 2: Age Calculator
#Take birth year as input from the user and calculate 
#and print their current age. (Current year: 2024)

#Example Output:
#Enter your birth year: 2000
#Your age is: 24 years old

# %%
current_year = 2026
birth_year = int(input("Enter your birth year:"))
age = current_year - birth_year

print("Your age is" , age , "years old")
# Out:
# Enter your birth year: 2003
# Your age is 23 years old
