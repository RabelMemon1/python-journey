# %%
#Scenario: Unique Website Visitors 🌐
#A website wants to track unique visitors in a day.
#Data
#visitors = {"Ali", "Sara", "Ahmed", "Ali", "Zara", "Sara"}
#Tasks
#Print the unique visitors list.
#Add a new visitor "Hassan".
#Check if "Sara" visited the website.
#Remove "Ahmed" from the visitor list.
#Print the final set of visitors.
#💡 Hint: Sets automatically remove duplicates.

# %%
visitors = {"Ali", "Sara", "Ahmed", "Ali", "Zara", "Sara"}

#Print the unique visitors list.
print(f"Visitors on a Website: {visitors}")

#Add a new visitor "Hassan".
visitors.add("Hassan")
print(f"Visitors on a Website: {visitors}")

#Check if "Sara" visited the website.
if "Sara" in visitors:
    print("True")

#Remove "Ahmed" from the visitor list.
visitors.remove("Ahmed")
print(f"Visitors on a Website: {visitors}")
# Out:
# Visitors on a Website: {'Sara', 'Zara', 'Ali', 'Ahmed'}
# Visitors on a Website: {'Sara', 'Ali', 'Zara', 'Hassan', 'Ahmed'}
# True
# Visitors on a Website: {'Sara', 'Ali', 'Zara', 'Hassan'}
